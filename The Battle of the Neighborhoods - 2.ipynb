# %% [markdown]
# <center> <p style="font-size:30px"> The Battle of the Neighborhoods - Part 2 </p> </center>

# %% [markdown]
# # Let's import the libraries

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

import folium # map rendering library

# %% [markdown]
# ### Let's obtain the data as a dataframe. After that, we'll perform some data-cleaning in order to eliminate those rows that contains "Not assigned data" or similars. We will also merge the repeated postal codes with different neighborhoods associated. This will conclude the pre-processing part.

# %%
df = pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')
df = df[0]
dff = df.drop( df[(df['Borough']=='Not assigned')].index)
dff = dff.reset_index(drop=True) #Let's reset the index

# %%
dff.columns=(['Postal Code', 'Borough','Neighborhood'])
dff.head()
df3= dff.groupby(['Postal Code', 'Borough'])['Neighborhood'].apply(list).apply(lambda x: ", ".join(x)).to_frame()
df3 = df3.reset_index() #Let's add the index to each row

# %% [markdown]
# ## It's time to merge the coordinates (longitude and latituted) to the dataframe df3

# %%
coords = pd.read_csv('https://cocl.us/Geospatial_data')
DF = df3.merge(coords, on="Postal Code")

# %% [markdown]
# ## Creating a map.
# ### Now we will reduce the dataframe and we'll take into account only the Boroughs that contains the word 'Toronto'.

# %%
address = 'Toronto' 

geolocator = Nominatim(user_agent="TO_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geographic coordinates of Toronto are {}, {}.'.format(latitude, longitude))

DFF = DF[DF['Borough'].str.contains("Toronto")].reset_index(drop=True) #Reduced dataframe

toronto_map2 = folium.Map(location=[latitude, longitude],zoom_start=13)
# Now let's add some markers to map
for lat, lng, borough, neighborhood in zip(DFF['Latitude'], DFF['Longitude'], DFF['Borough'], DFF['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=2.5,
        popup=label,
        color='red',
        fill=False,
        fill_opacity=0.9,
        parse_html=False).add_to(toronto_map2)  
toronto_map2
# Out:
# The geographic coordinates of Toronto are 43.6534817, -79.3839347.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Foursquare Credentials
CLIENT_ID = 'DQEZG2S4QT5HDY2BHE3VOCSPNHAZFZAQ1UGM0VWNJKSOHBTK' #  Foursquare ID
CLIENT_SECRET = 'ZJETNCGS2QPKYSOVFZOI4XG1NNP4CBWNMLAD4NL3KAWX0UOL' #  Foursquare Secret
VERSION = '20180605' # Foursquare API version

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):  
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)       
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)  
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])
    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
LIMIT=50
toronto_venues = getNearbyVenues(names=DFF['Neighborhood'],
                                   latitudes=DFF['Latitude'],
                                   longitudes=DFF['Longitude']
                                  )
# Out:
# The Beaches
# The Danforth West, Riverdale
# India Bazaar, The Beaches West
# Studio District
# Lawrence Park
# Davisville North
# North Toronto West, Lawrence Park
# Davisville
# Moore Park, Summerhill East
# Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park
# Rosedale
# St. James Town, Cabbagetown
# Church and Wellesley
# Regent Park, Harbourfront
# Garden District, Ryerson
# St. James Town
# Berczy Park
# Central Bay Street
# Richmond, Adelaide, King
# Harbourfront East, Union Station, Toronto Islands
# Toronto Dominion Centre, Design Exchange
# Commerce Court, Victoria Hotel
# Roselawn
# Forest Hill North & West, Forest Hill Road Park
# The Annex, North Midtown, Yorkville
# University of Toronto, Harbord
# Kensington Market, Chinatown, Grange Park
# CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport
# Stn A PO Boxes
# First Canadian Place, Underground city
# Christie
# Dufferin, Dovercourt Village
# Little Portugal, Trinity
# Brockton, Parkdale Village, Exhibition Place
# High Park, The Junction South
# Parkdale, Roncesvalles
# Runnymede, Swansea
# Queen's Park, Ontario Provincial Government
# Business reply mail Processing Centre, South Central Letter Processing Plant Toronto

# %%
toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()

def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

num_top_venues = 20

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head(10)
# Out:
#                                         Neighborhood 1st Most Common Venue  \
# 0                                        Berczy Park           Coffee Shop
# 1       Brockton, Parkdale Village, Exhibition Place                  Café
# 2  Business reply mail Processing Centre, South C...    Light Rail Station
# 3  CN Tower, King and Spadina, Railway Lands, Har...       Airport Service
# 4                                 Central Bay Street           Coffee Shop
# 5                                           Christie         Grocery Store
# 6                               Church and Wellesley           Coffee Shop
# 7                     Commerce Court, Victoria Hotel                 Hotel
# 8                                         Davisville           Pizza Place
# 9                                   Davisville North                  Park
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0           Cheese Shop                  Café          Cocktail Bar
# 1        Breakfast Spot                Bakery           Coffee Shop
# 2           Yoga Studio        Farmers Market               Butcher
# 3        Airport Lounge      Airport Terminal           Coffee Shop
# 4    Italian Restaurant        Sandwich Place       Bubble Tea Shop
# 5                  Café                  Park            Baby Store
# 6   Japanese Restaurant           Yoga Studio               Gay Bar
# 7           Coffee Shop                  Café            Restaurant
# 8        Sandwich Place          Dessert Shop      Sushi Restaurant
# 9        Breakfast Spot           Pizza Place        Sandwich Place
#
#     5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0                Beer Bar    Seafood Restaurant        Farmers Market
# 1  Furniture / Home Store     Convenience Store                   Bar
# 2                     Spa         Auto Workshop      Recording Studio
# 3         Harbor / Marina                 Plane   Rental Car Location
# 4            Burger Joint                  Café              Wine Bar
# 5             Coffee Shop           Candy Store            Restaurant
# 6              Restaurant      Sushi Restaurant           Men's Store
# 7                     Gym   American Restaurant   Japanese Restaurant
# 8             Coffee Shop    Italian Restaurant                  Café
# 9    Gym / Fitness Center      Department Store          Dance Studio
#
#         8th Most Common Venue 9th Most Common Venue  \
# 0                      Bakery            Restaurant
# 1                     Stadium             Nightclub
# 2                 Pizza Place         Burrito Place
# 3            Sculpture Garden              Boutique
# 4  Modern European Restaurant   Japanese Restaurant
# 5                       Diner    Italian Restaurant
# 6            Theme Restaurant     Indian Restaurant
# 7                   Gastropub    Seafood Restaurant
# 8                         Gym    Seafood Restaurant
# 9                       Hotel     Food & Drink Shop
#
#       10th Most Common Venue 11th Most Common Venue 12th Most Common Venue  \
# 0                   Pharmacy                  Hotel         Breakfast Spot
# 1               Intersection             Restaurant           Climbing Gym
# 2       Gym / Fitness Center             Restaurant             Skate Park
# 3                        Bar          Boat or Ferry           Airport Gate
# 4  Middle Eastern Restaurant     Miscellaneous Shop                 Office
# 5                  Nightclub    Fried Chicken Joint          Garden Center
# 6                 Hobby Shop      Martial Arts Dojo                  Diner
# 7              Deli / Bodega                   Park               Beer Bar
# 8        Japanese Restaurant             Restaurant                Brewery
# 9           Cuban Restaurant    Distribution Center         Discount Store
#
#     13th Most Common Venue 14th Most Common Venue 15th Most Common Venue  \
# 0                   Bistro      Indian Restaurant       Department Store
# 1                      Gym          Grocery Store  Performing Arts Venue
# 2                     Park             Comic Shop                Brewery
# 3       Airport Food Court                Airport                 Garden
# 4  New American Restaurant         Ice Cream Shop                   Park
# 5             Dessert Shop       Department Store          Deli / Bodega
# 6                 Sake Bar                Theater         Ice Cream Shop
# 7     Gym / Fitness Center         Sandwich Place         Ice Cream Shop
# 8        Indian Restaurant         Farmers Market               Pharmacy
# 9                    Diner           Dessert Shop          Deli / Bodega
#
#   16th Most Common Venue 17th Most Common Venue 18th Most Common Venue  \
# 0                  Beach     Basketball Stadium               Creperie
# 1     Italian Restaurant          Burrito Place                 Office
# 2                 Garden          Garden Center   Fast Food Restaurant
# 3          Deli / Bodega             Donut Shop       Doner Restaurant
# 4            Pizza Place             Poke Place      Indian Restaurant
# 5           Dance Studio            Gaming Cafe           Cupcake Shop
# 6         Breakfast Spot       Ramen Restaurant                    Pub
# 7            Salad Place              Bookstore                 Bakery
# 8                  Diner         Discount Store        Thai Restaurant
# 9           Cupcake Shop               Creperie       Doner Restaurant
#
#   19th Most Common Venue 20th Most Common Venue
# 0              Jazz Club     Italian Restaurant
# 1              Pet Store          Deli / Bodega
# 2       Department Store          Deli / Bodega
# 3                Dog Run    Distribution Center
# 4              Gastropub                  Hotel
# 5                 Garden       Cuban Restaurant
# 6        Bubble Tea Shop               Beer Bar
# 7                    Pub            Tailor Shop
# 8           Gourmet Shop                   Park
# 9        Coworking Space         Cosmetics Shop

# %% [markdown]
# <p style='font-size:20px'> This previous dataframe shows the 20 most common venues of each Neighbour. Which one is the best if we want to open a gym? The answer to this question is, at first, simple: the one that doesn't have a gym within its 20 most common venues. Actually, the answer can be a little bit more elaborated.</p>

# %% [markdown]
# ## Can we take into account more features in order to pick the best place? Yes!

# %% [markdown]
# <p style='font-size:20px'> We can combine the neighborhoods that don't have many gyms or fitness centers but do have hotels or cafés.

# %%
toronto_possible_1 = neighborhoods_venues_sorted[(neighborhoods_venues_sorted['1st Most Common Venue']=='Hotel') | (neighborhoods_venues_sorted['2nd Most Common Venue']== 'Café') ].reset_index(drop=True)
toronto_possible_2 = neighborhoods_venues_sorted[(neighborhoods_venues_sorted['1st Most Common Venue']=='Café') | (neighborhoods_venues_sorted['2nd Most Common Venue']== 'Hotel') ].reset_index(drop=True)

# %% [markdown]
# <p style='font-size:20px'> toronto_possible_1 and toronto_possible_2 are two dataframes that contains the neighborhoods whose 1st or 2nd most common venue are cafés or hotels.</p>

# %%
toronto_possible_1
# Out:
#                                Neighborhood 1st Most Common Venue  \
# 0                                  Christie         Grocery Store
# 1            Commerce Court, Victoria Hotel                 Hotel
# 2                  Garden District, Ryerson           Coffee Shop
# 3             High Park, The Junction South    Mexican Restaurant
# 4                  Little Portugal, Trinity                   Bar
# 5                  Richmond, Adelaide, King           Coffee Shop
# 6       The Annex, North Midtown, Yorkville        Sandwich Place
# 7  Toronto Dominion Centre, Design Exchange           Coffee Shop
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0                  Café                  Park            Baby Store
# 1           Coffee Shop                  Café            Restaurant
# 2                  Café        Clothing Store        Cosmetics Shop
# 3                  Café       Thai Restaurant                  Park
# 4                  Café            Restaurant           Coffee Shop
# 5                  Café            Steakhouse          Concert Hall
# 6                  Café           Coffee Shop                   Pub
# 7                  Café    Seafood Restaurant                 Hotel
#
#   5th Most Common Venue  6th Most Common Venue 7th Most Common Venue  \
# 0           Coffee Shop            Candy Store            Restaurant
# 1                   Gym    American Restaurant   Japanese Restaurant
# 2      Ramen Restaurant               Tea Room               Theater
# 3        Discount Store                  Diner             Bookstore
# 4           Men's Store  Vietnamese Restaurant      Asian Restaurant
# 5                 Hotel             Restaurant   American Restaurant
# 6        History Museum           Liquor Store             BBQ Joint
# 7   Japanese Restaurant             Restaurant              Beer Bar
#
#            8th Most Common Venue    9th Most Common Venue  \
# 0                          Diner       Italian Restaurant
# 1                      Gastropub       Seafood Restaurant
# 2                      Bookstore     Fast Food Restaurant
# 3             Italian Restaurant              Music Venue
# 4  Vegetarian / Vegan Restaurant                     Park
# 5                    Pizza Place  New American Restaurant
# 6              Indian Restaurant              Cheese Shop
# 7                         Bakery     Gym / Fitness Center
#
#       10th Most Common Venue 11th Most Common Venue 12th Most Common Venue  \
# 0                  Nightclub    Fried Chicken Joint          Garden Center
# 1              Deli / Bodega                   Park               Beer Bar
# 2        Japanese Restaurant                  Plaza           Burger Joint
# 3  Cajun / Creole Restaurant   Fast Food Restaurant              Speakeasy
# 4    New American Restaurant     Miscellaneous Shop     Mexican Restaurant
# 5           Department Store   Gym / Fitness Center     Seafood Restaurant
# 6          Convenience Store            Pizza Place               Pharmacy
# 7              Deli / Bodega     Basketball Stadium               Wine Bar
#
#       13th Most Common Venue 14th Most Common Venue 15th Most Common Venue  \
# 0               Dessert Shop       Department Store          Deli / Bodega
# 1       Gym / Fitness Center         Sandwich Place         Ice Cream Shop
# 2                      Hotel          Burrito Place            Pizza Place
# 3                        Bar                 Bakery            Flea Market
# 4           Greek Restaurant      Korean Restaurant              Juice Bar
# 5         Salon / Barbershop              Bookstore   Brazilian Restaurant
# 6  Middle Eastern Restaurant           Burger Joint                   Park
# 7                Pizza Place                    Pub         Sandwich Place
#
#    16th Most Common Venue         17th Most Common Venue  \
# 0            Dance Studio                    Gaming Cafe
# 1             Salad Place                      Bookstore
# 2      Italian Restaurant                 Sandwich Place
# 3  Furniture / Home Store                      Gastropub
# 4     Japanese Restaurant             Italian Restaurant
# 5                   Plaza                  Deli / Bodega
# 6              Donut Shop  Vegetarian / Vegan Restaurant
# 7             Salad Place                      Bookstore
#
#     18th Most Common Venue 19th Most Common Venue 20th Most Common Venue
# 0             Cupcake Shop                 Garden       Cuban Restaurant
# 1                   Bakery                    Pub            Tailor Shop
# 2  New American Restaurant          Shopping Mall                   Lake
# 3      Fried Chicken Joint           Antique Shop    Arts & Crafts Store
# 4              Pizza Place         Ice Cream Shop               Wine Bar
# 5            Burrito Place                    Gym    Japanese Restaurant
# 6             Dance Studio          Deli / Bodega       Department Store
# 7                    Plaza         Ice Cream Shop              Speakeasy

# %%
toronto_possible_2
# Out:
#                                    Neighborhood 1st Most Common Venue  \
# 0  Brockton, Parkdale Village, Exhibition Place                  Café
# 1        First Canadian Place, Underground city                  Café
# 2     Kensington Market, Chinatown, Grange Park                  Café
# 3                            Runnymede, Swansea                  Café
# 4                                St. James Town                  Café
# 5                                Stn A PO Boxes                  Café
# 6                               Studio District                  Café
# 7                University of Toronto, Harbord                  Café
#
#   2nd Most Common Venue          3rd Most Common Venue 4th Most Common Venue  \
# 0        Breakfast Spot                         Bakery           Coffee Shop
# 1           Coffee Shop                     Restaurant   American Restaurant
# 2    Mexican Restaurant  Vegetarian / Vegan Restaurant           Coffee Shop
# 3           Coffee Shop                    Pizza Place                   Pub
# 4           Coffee Shop                 Cosmetics Shop              Creperie
# 5            Restaurant                       Beer Bar          Cocktail Bar
# 6           Coffee Shop            American Restaurant                Bakery
# 7            Restaurant                            Bar             Bookstore
#
#     5th Most Common Venue  6th Most Common Venue 7th Most Common Venue  \
# 0  Furniture / Home Store      Convenience Store                   Bar
# 1      Seafood Restaurant          Deli / Bodega          Concert Hall
# 2            Burger Joint  Vietnamese Restaurant                   Bar
# 3        Sushi Restaurant     Italian Restaurant           Yoga Studio
# 4          Farmers Market              Gastropub            Restaurant
# 5             Coffee Shop               Creperie        Farmers Market
# 6                 Brewery              Gastropub              Wine Bar
# 7          Sandwich Place    Japanese Restaurant                Bakery
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue  \
# 0               Stadium             Nightclub           Intersection
# 1                 Hotel                   Gym               Tea Room
# 2           Pizza Place          Dessert Shop            Record Shop
# 3             Bookstore                   Bar          Smoothie Shop
# 4    Seafood Restaurant                 Hotel      German Restaurant
# 5    Seafood Restaurant           Cheese Shop                  Hotel
# 6           Fish Market             Pet Store                   Park
# 7           Yoga Studio              Beer Bar             Beer Store
#
#       11th Most Common Venue     12th Most Common Venue  \
# 0                 Restaurant               Climbing Gym
# 1                        Bar                     Bakery
# 2       Caribbean Restaurant                Cheese Shop
# 3                IT Services             Sandwich Place
# 4  Middle Eastern Restaurant                       Park
# 5               Liquor Store                       Park
# 6  Middle Eastern Restaurant  Latin American Restaurant
# 7         Italian Restaurant               Dessert Shop
#
#   13th Most Common Venue 14th Most Common Venue   15th Most Common Venue  \
# 0                    Gym          Grocery Store    Performing Arts Venue
# 1              Speakeasy   Gym / Fitness Center  New American Restaurant
# 2                   Park        Organic Grocery             Noodle House
# 3             Restaurant               Boutique       Falafel Restaurant
# 4               Beer Bar         Ice Cream Shop   Furniture / Home Store
# 5     Basketball Stadium                 Bistro  Comfort Food Restaurant
# 6     Italian Restaurant         Ice Cream Shop     Gym / Fitness Center
# 7                    Pub     Chinese Restaurant             Noodle House
#
#     16th Most Common Venue 17th Most Common Venue   18th Most Common Venue  \
# 0       Italian Restaurant          Burrito Place                   Office
# 1                Bookstore            Salad Place                 Beer Bar
# 2  Comfort Food Restaurant               Wine Bar       Belgian Restaurant
# 3                    Diner          Burrito Place             Dessert Shop
# 4                Bookstore       Department Store             Camera Store
# 5         Department Store         Breakfast Spot                Irish Pub
# 6                  Gay Bar      Convenience Store                    Diner
# 7                Nightclub  College Arts Building  Comfort Food Restaurant
#
#       19th Most Common Venue  20th Most Common Venue
# 0                  Pet Store           Deli / Bodega
# 1           Greek Restaurant  Gluten-free Restaurant
# 2           Doner Restaurant              Donut Shop
# 3  Latin American Restaurant                    Bank
# 4             Breakfast Spot      Italian Restaurant
# 5         Italian Restaurant     Japanese Restaurant
# 6            Coworking Space      Seafood Restaurant
# 7              Moving Target                    Bank

# %% [markdown]
# <p style="font-size:20px"> Taking a look at these two dataframes, we can see that there are some neighborhoods that do not have gyms nearby but that do have many cafes and some hotels.

# %%
TO1 = toronto_possible_1[(toronto_possible_1['Neighborhood']=='Toronto Dominion Centre, Design Exchange') | 
                   (toronto_possible_1['Neighborhood']== 'Garden District, Ryerson')].reset_index(drop=True)

# %%
TO2 = toronto_possible_2[(toronto_possible_2['Neighborhood']== 'Kensington Market, Chinatown, Grange Park')  |
                   (toronto_possible_2['Neighborhood']=='Runnymede, Swansea')].reset_index(drop=True)

# %%
T=[TO1,TO2]
T=pd.concat(T).reset_index(drop=True)
T
# Out:
#                                 Neighborhood 1st Most Common Venue  \
# 0                   Garden District, Ryerson           Coffee Shop
# 1   Toronto Dominion Centre, Design Exchange           Coffee Shop
# 2  Kensington Market, Chinatown, Grange Park                  Café
# 3                         Runnymede, Swansea                  Café
#
#   2nd Most Common Venue          3rd Most Common Venue 4th Most Common Venue  \
# 0                  Café                 Clothing Store        Cosmetics Shop
# 1                  Café             Seafood Restaurant                 Hotel
# 2    Mexican Restaurant  Vegetarian / Vegan Restaurant           Coffee Shop
# 3           Coffee Shop                    Pizza Place                   Pub
#
#   5th Most Common Venue  6th Most Common Venue 7th Most Common Venue  \
# 0      Ramen Restaurant               Tea Room               Theater
# 1   Japanese Restaurant             Restaurant              Beer Bar
# 2          Burger Joint  Vietnamese Restaurant                   Bar
# 3      Sushi Restaurant     Italian Restaurant           Yoga Studio
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue  \
# 0             Bookstore  Fast Food Restaurant    Japanese Restaurant
# 1                Bakery  Gym / Fitness Center          Deli / Bodega
# 2           Pizza Place          Dessert Shop            Record Shop
# 3             Bookstore                   Bar          Smoothie Shop
#
#   11th Most Common Venue 12th Most Common Venue 13th Most Common Venue  \
# 0                  Plaza           Burger Joint                  Hotel
# 1     Basketball Stadium               Wine Bar            Pizza Place
# 2   Caribbean Restaurant            Cheese Shop                   Park
# 3            IT Services         Sandwich Place             Restaurant
#
#   14th Most Common Venue 15th Most Common Venue   16th Most Common Venue  \
# 0          Burrito Place            Pizza Place       Italian Restaurant
# 1                    Pub         Sandwich Place              Salad Place
# 2        Organic Grocery           Noodle House  Comfort Food Restaurant
# 3               Boutique     Falafel Restaurant                    Diner
#
#   17th Most Common Venue   18th Most Common Venue     19th Most Common Venue  \
# 0         Sandwich Place  New American Restaurant              Shopping Mall
# 1              Bookstore                    Plaza             Ice Cream Shop
# 2               Wine Bar       Belgian Restaurant           Doner Restaurant
# 3          Burrito Place             Dessert Shop  Latin American Restaurant
#
#   20th Most Common Venue
# 0                   Lake
# 1              Speakeasy
# 2             Donut Shop
# 3                   Bank

# %% [markdown]
# <p style="font-size:20px"> As it can be observed in the T dataframe, there are a some neighborhoods where it could be a nice idea to place a Gym or a Fitness Center. </p>

# %%
#Let's make a map with the zones where it is suitable to put a gym
TOO1 = DFF[(DFF['Neighborhood']=='Toronto Dominion Centre, Design Exchange') | 
                   (DFF['Neighborhood']== 'Garden District, Ryerson') |
                   (DFF['Neighborhood']== 'Kensington Market, Chinatown, Grange Park')  |
                   (DFF['Neighborhood']=='Runnymede, Swansea') ].reset_index(drop=True)

# %%
tormap = folium.Map(location=[latitude, longitude],zoom_start=13)
# Now let's add some markers to map
for lat, lng, borough, neighborhood in zip(TOO1['Latitude'], TOO1['Longitude'], TOO1['Borough'], TOO1['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=10,
        popup=label,
        color='red',
        fill=False,
        fill_opacity=0.9,
        parse_html=False).add_to(tormap)  
tormap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <p style="font-size:20px">  So there are four potential places to put a Fitness Center. For a further analysis, it could be useful to take into account other features as the average income of the neighborhood, the average age, and so on. But, since this is a first project, I think that determining the places based on the number of similar venues near the neighborhood and the number of cafés or hotels that there are is a good starting point.
